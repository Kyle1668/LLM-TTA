# %%
import os
import sys
import torch
import faiss
import argparse
import numpy as np
import pandas as pd
import torch.nn.functional as F
import nlpaug.augmenter.word as naw
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModel
from tqdm import tqdm
tqdm.pandas()

from util_modeling import get_model_objects
from util_data import get_formatted_dataset, get_num_labels
from adaptive_methods import get_paraphrase_augmentations

# %%
datasets = get_formatted_dataset("boss_sentiment")
train_set = datasets["train"].to_pandas().drop(columns=["__index_level_0__"])
test_set = datasets["validation"].to_pandas().drop(columns=["__index_level_0__"])
display(train_set.head())
display(test_set.head())
# Out:
#                                                 text  label
# 0                                One of my favorites      1
# 1  My favorite Coarse Sea Salt brand I know about...      1
# 2  Love the top! It fits a little tight, so can b...      1
# 3  very nice & I like it for everything I used it...      1
# 4                                   Awesome product!      1
#                                                 text  label
# 0            Great tool for usage with cutting dies!      1
# 1                                            Perfect      1
# 2          Good replacement ink for my epson printer      1
# 3  Excellent product. Works as designed/described...      1
# 4  The lint eater is amazing! We recently bought ...      1

# %% [markdown]
# ## Create Embeddings

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tokenizer = AutoTokenizer.from_pretrained("princeton-nlp/sup-simcse-roberta-large")
model = AutoModel.from_pretrained("princeton-nlp/sup-simcse-roberta-large").to(device).eval()

# %%
amazon_embeddings = torch.load("notebooks/dynasent_analysis/amazon_embeddings.pt")
train_set["embedding"] = amazon_embeddings.tolist()
train_set.head()
# Out:
#                                                 text  label  \
# 0                                One of my favorites      1
# 1  My favorite Coarse Sea Salt brand I know about...      1
# 2  Love the top! It fits a little tight, so can b...      1
# 3  very nice & I like it for everything I used it...      1
# 4                                   Awesome product!      1
#
#                                            embedding
# 0  [0.6473956108093262, 0.13781151175498962, 0.37...
# 1  [0.8231244087219238, -0.1266566663980484, -0.0...
# 2  [0.6754499673843384, 0.36946073174476624, -0.0...
# 3  [0.8606024980545044, -0.2657198905944824, -0.5...
# 4  [0.7306466102600098, -0.3295357823371887, 0.24...

# %%
def get_embedding(text):
    tokens = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512).to(device)
    return model(**tokens)["pooler_output"].detach().cpu().numpy()

test_set["embedding"] = test_set["text"].progress_apply(get_embedding)
test_set.head()
# Out:
# 100%|██████████| 38904/38904 [10:17<00:00, 63.00it/s]
#                                                 text  label  \
# 0            Great tool for usage with cutting dies!      1
# 1                                            Perfect      1
# 2          Good replacement ink for my epson printer      1
# 3  Excellent product. Works as designed/described...      1
# 4  The lint eater is amazing! We recently bought ...      1
#
#                                            embedding
# 0  [[0.16313213, -0.49149835, -0.4596042, 0.33255...
# 1  [[-0.50077945, -0.3658858, 0.36897424, -0.5260...
# 2  [[0.002162329, -0.42244336, -0.508097, 0.25507...
# 3  [[0.5475646, -0.49577963, -0.4613782, 0.066582...
# 4  [[0.72862387, 0.39312103, -0.14261693, -0.2165...

# %%
test_set_embeddings = torch.Tensor(np.stack(test_set["embedding"])).squeeze(1)
display(test_set_embeddings.shape)
torch.save(test_set_embeddings, "notebooks/dynasent_analysis/amazon_validation_embeddings.pt")
# Out:
# torch.Size([38904, 1024])

# %%
labels = train_set["label"].unique()
vector_stores = {}
centroids = {}
centroid_examples = {}
k = 10
d = 1024

for label in labels:
    label_instances = train_set[train_set["label"] == label]
    label_embeddings = np.stack(label_instances["embedding"].to_numpy()).astype(np.float32)
    
    faiss.normalize_L2(label_embeddings)
    vector_stores[label] = faiss.IndexFlatIP(d)
    vector_stores[label].add(label_embeddings)
    centroids[label] = label_embeddings.mean(axis=0)
    
    cosine_sims, centroid_example_indices = vector_stores[label].search(centroids[label].reshape(1, -1), k)
    centroid_examples[label] = []
    for index in centroid_example_indices[0]:
        centroid_examples[label].append(label_instances.iloc[index]["text"])

centroid_examples
# Out:
# {1: ['Really a very nice product. Works great and so easy to use, I really LOVE it!',
#   'Great product and quality. I recommend this product.',
#   'Really Great Product, soildly built, More than happy with perfomance, and I would ecomend this product to everyone who has a need....Its all Good!',
#   'Excellent product, I love it.',
#   'I like this product.',
#   'good product. I would buy it again. Excellent',
#   'very nice & I like it for everything I used it for! A+',
#   'Great product, highly recommend.',
#   'Works perfectly for what I need it for. Feels very well built. It also came with extra fuses which was a nice surprise. I would highly recommend this to anyone in need of such an item.',
#   'Great product.'],
#  2: ["A bit pricey for a piece of plastic for starters. I do like the feel of it and it does help me shoot more with ease. The complaints start with the poor casting on mine. I had to use a razor blade to shave excess material that rest on top of the buffer tube. It was an easy fix but shouldn't be required by the customer. 2nd complaint is the battery storage caps. They poorly screw in and could easily be lost, not too mention their hard to put back in. They should come tethered to the saddle instead i had to jerry rig some paracord to prevent loss. Im still happy with the purchase but wish their was better quality in this product.",
#   "I am not terribly impressed with this case, glad I didn't pay too much for it. It fits very loosely, not so much that it will fall off, but it is very sloppy. Also, it's a bit thicker than I'd like. Aside from that it's not terrible, with a nice rubbery texture and decent grip surface. The buttons are all functional and you don't have to press hard to get them t function. It also isn't a bad looking case, but you get what you pay for. I'll be trying a different case out, personally.",
#   "The AmazonBasics calculator is decent but not something I'm over the moon about. It works fine and does the job well, but the product doesn't strike me as high quality. When I received it, one of the feet was missing and there were scuffs marring the screen (not the kind I can remove either). I was rather surprised about the defects seeing that it was in bubble wrap snuggly tucked inside a box inside the mailer. The paint, while attractive enough, looks as though it'll wear away in time and the calculator is made from very light plastic. It's not all bad though, the buttons are nicely sized and I like that there are different colors for the separate functions. The 'clear entry' button being so far from the 'clear all' one makes for less mistakes on my part, and that I love, seeing as most calculators feature them right next to each other. Even though it's dual-powered and will shut off within five to seven minutes, there is an 'off' button which is useful to those who like to conserve wherever possible. I don't quite like where the 'equals' button is as it's rather awkward to use, but that's a nitpick. Surprisingly, there is a one-year warranty and the price seems fair for this type of calculator. If all you need is a basic calculator for your desk, in the kitchen, or wherever, this'll do.",
#   'It\'s ok for the money, one of those things where "you get what you pay for". First one I ordered came in with a dent on one of the back corners, this should be packaged better. Sent it back, second one arrived with a corner dented also, but it wasn\'t as bad as the first, decided to just keep it. Where this box fails, is the bottom, it\'s very flimsy. I was afraid to put anything that had any weight in it. I fixed this by cutting a piece of 3/4" plywood the same dimensions as the box. I mounted the plywood to the trailer tongue, and mounted the box to the plywood. I\'m also planning on getting some weather stripping for the lid to make sure no water gets in. If they would have made the bottom stronger, and sealed the top better, this would be a much better box. I\'m also not crazy about the hinge system for the lid, just some plastic pins. I would have liked to see a metal rod.',
#   "The ends are fairly sharp, but some were duller than others, many weren't real even either. So when stamping something, it would leave small areas not cut. They felt sturdy and seemed like they would work great, but some ends have chipped a little l, making cuts harder as it has to be rotated for each piece. All in all, ok for the price, the smaller ones seem better, but I probably wouldn't buy it again unless it was for a single use.\n\nIf this review helps, I would greatly appreciate it if you liked it. I strive to write reviews to help others as I base many of my purchases off of reviews.",
#   'Nothing special. Just like every other strap of its kind. I compared it to other poly straps I have and it\'s OK. No better and no worse. Price was good. It took a long time to come. Leather ends seem OK. I mention that because it appears to be the main complaint..I\'m using it as a spare so it should be OK. I\'m a little disappointed. I\'m used to a higher quality from EB products. It is very adjustable and should be able to be used by nearly everyone. I don\'t perform a lot of antics on stage, it\'s just me and the axe. I don\'t expect any problems. Hope this helps. Small "thumbs up" to Amazon.',
#   "I was expecting this to be a little easier than what it was. It's a messy job, takes too long to put on, and doesn't protect the corners of the phone. I really wanted to like this, but it just was worth it. I have an HTC One btw.\n\nPros: Good quality everything.\nCons: Too hard to put on (just get a TPU case)\nDoesn't stay put when apply some pressure and edges don't stay stuck.\nScreen cover makes the screen look rainbowy. Looses sharpness.\n\nUPDATE: After a few days of using only the back of this case (the screen protector bothered me) this seems to protect pretty decently from scratches(not any sort of impact of course). Also, after it dries for a full day, the case stays on pretty well. It makes the phone feel a bit rubbery which isn't a bad thing either.\n\nIt's more of a backup to go underneath another case (which I will be ordering)",
#   "My expectations were probably a bit high since I have purchased Twelve South products in the past and been pleased.\n\nI would say the overall build quality, if you can call it that, is a sub par. The main rail and dividing bar are made of plastic. I had incorrectly assumed that they were aluminum. Certainly not a deal break at this price, but the dividing bar shifts and moves with regular use of our keyboard and trackpad. I had hoped that this was a more stable solution, but it requires some fiddling every once in a while to assure the components are staying in place.\n\nOverall, its not a bad purchase, but one that I likely wouldn't repeat.",
#   'Not even Close to black. It is dark Espresso brown. If you have black items around it that you want to match, it will STAND OUT BADLY!\nVery misleading for Amazon to names these "Deep Black" or Cinnamon. It does say Mocha Black in the title but guess I figured a few of the trim pieces might have some brown in them. Also a piece of laminate broke off when inserting a peg. I have to get a new piece because it is right in front where everybody can see. It was very easy to install and does look more expensive that it was. The overall quality for this price range would be a 4 or 5. I\'m Giving it 3 stars now for the bad description. I will update again once I see how hard it is to get a new piece for the front.\n\nUpdate 7-5-15\n\nOkay so first i must say we have grown to like this unit. It looks very nice and we get compliments on it all the time. It also works great for sitting under a large projector screen and fits a large center speaker right in the middle. I had small small piece that was chipped in the front and I contacted the distributor for Sonax. It was a small chip but it was right ion front and I wasn\'t having it. They sent out a new piece ASAP no questions asked but serial number/ batch number! It was at my house FAST! However on unwrapping the replacement I can\'t help to feel they were either overly concerned about damage or sending me a message that I was too picky? The amount of cardboard wrap that came with the replacement was possibly more than came with the entire unit. LOL what a waste. Was gonna upgrade to 4 stars but leaving it at 3 now. Now I get to figure out how to get rid of all this junk. :)\n\nSee pic. Little skinny item in middle is the part, the rest is cardboard wrap.',
#   "I give this product a 4 star because it does its job well. However, the build quality is not that good. Also to keep in mind there is only 1 main/master switch at the side of the product to turn off/on so you can't independently turn off/on the different plugs. It's okay for the price. My only concern is that the holes where the plug goes in, they don't really fit plugs of all my electrical appliances. I have to push quite hard because something seems to be blocking the plug so it doesn't go all the way into the holes.\n\nI would recommend it if price is a constraint otherwise go for a more expensive alternatives but with better build quality and functionality. But it does its job well."],
#  0: ['EDIT: I\'m leaving my original review below but have to note that I ended up returning this kit. The hi-hat pad went bad within two weeks of light use (I\'m a adult just doing beginner level exercises on it 20 minutes a day at most). Although I originally praised the build quality, after very light wear other problems arose. The build quality here is actually quite horrible. There are drum kit game controllers for Rock Band that supersede this quality. I think Alesis should be ashamed of this product. I\'ve written them about the Mac OS compatibility and they responded saying they could not reproduce the problem. The hi-hat going out was the last straw.\n\nAmazon has been very good about the return but boxing this thing up is a utter nightmare, it comes in a very very small box for it\'s size. Do not waste your time or money on this kit unless you\'re buying it for a five year old to learn on. It is not worthy of an adult. I would not buy this kit for my child either. I\'ve communicated with others in the Alesis forums on the vendors website that are reporting quality problems with the DM6 and DM10 kits also. I\'m not seeing this type of negative reports for Rolands products. You generally get what you pay for but in this case I believe we have a very high defect rate on an entire line of products that aren\'t well built and a vendor who truly does not care. That has been my personal experience. I suggest going to the Alesis forums and doing some research for yourself there to decide if it\'s worth the risk. With all the pain its caused me, I would say the DM Lite is one of the worst purchases I\'ve made in the last ten years. If you intend to really use it as a musician for MIDI purposes, band rehearsal, etc.. please take my advise on look elsewhere for the sake of your music and your band I would avoid the Alesis branded e-drum products... My original review is below...\n\nAfter much debate I decided to give the DM Lite a try over the Roland TD4KP. My objective is to have a high quality, portable drum kit for home studio use that could also be taken to coffee houses. From all demos I knew the TD4KP was a better designed product in terms of sound quality and portability (it just folds up) however the DM Lite cost less than half of the TD4KP and I was only seeing positive reviews, so I gave it a shot.\n\nWith the Alesis DM Lite, Alesis has provided a picture of this unit nicely folded on the products home page as if to say "me too" but the comparisons really stop there. The DM Lite does not fold up in the same way. In fact there was no design effort put into this kit having a fold up feature as the Roland kit does (Roland hold a patent on this feature) so Alesis is sort for falsely marketing this. I say "sort of" because they never claim the kit folds up they just show pictures of what it looks like out of the box on their site. To get it back to that state from being playable takes about 20 minutes. The sound module on the Roland unit is vastly superior to what Alesis delivers. Allow me to state the problems: First the quality of the kits themselves. The snare and toms sound ok. The kick is way too loud and regardless what speaker you put it through it distorts. The high hat and crash on the most natural sounding kit in the module is immediately recognizable to novice ears as fake. The samples are overall weak. The sound modules built in trainer and other beginner features combined with the quality of the kits mark this as a beginners product and that\'s unfortunate because the Roland kit I assumed it was a counterpart to is pro grade in every possible way. Designed to be portable for beginners intermediate and pros. That being said this kit is hard to beat at the price point for a beginner. Alesis sound module may not be up to Roland (it also cost half the price of the Roland kit), but it beats Simmons and D-Drums products in this price range. If you run the kit into a good PA with decent EQ options and add a reverb or ...
#   'I bought this product because of the ratings, but be warned that this product is not worth it. Spend a little more money and buy something that is going to do what it says. Granted, I got the product in a timely manner, the minute I started putting it together, pieces started breaking off/falling apart. Now I have so many loose pieces, I do not know what goes where. So disappointed.',
#   "If I could have 0 stars I would, this was complete Junk. Order a pair of these. Neither worked right out of the box, constant static, kept reacting as if I was pushing the mic button onmy headphone. Went back to the solid metal xtended I had and everythign worked perfectly. 1 of the 2 was lost by the time I filed a complaint so they only refunded me for 1. Was't worth the trouble returning of a few $$$.",
#   'Worst filament I have purchased to date. Very brittle. It was broken on the spool about 4 feet in (I saw it before I even opened the wrap - should have returned it then) so the first few feet were wasted. Breaks trying to load it. Breaks entering the extruder while printing. I have been able to get very few complete prints. By the way, this is first time I have written a negative review but this product has provided nothing but frustration.',
#   "SB has terrible customer service, Never returned my call. I called back and was greeted by a rude customer service rep.\n\nUpdate: TO BE FAIR; This picture is now changed and this may be an updated product from what I purchased THANK GOD. Mine did not include D rings and is slightly different and was slightly cheaper in cost. Very similar though. I still have it and it makes a ton of rattling noises, the oil pin snapped off the 1st time I opened it all the way and now it is really hard to use. I'm going to throw it away and buy a new one from another maker.",
#   "I debated whether I should give this case a one or two star rating. But seeing that it's of no use to me and will be returned, I opted for one star. Some might be able to live with the poor manufacturing and quality control, but not me. It was obvious when I first opened the package that something was wrong. The end with the power and headphone openings was clearly warped out of shape. I thought perhaps it would stretch tight once on the phone, but no chance. There case is very loose on that end and you can even see daylight through a gap. Shame too because I actually like the bevelled openings for the fingerprint reader.\n\nI also purchased the Cimo [Wave] which is a similar material and for much less it fits perfectly.",
#   "Do not buy.. I've been pleased with the normal dry Spigen offerings, but this one is very disappointing.\n\n1. Fit, the fit is not good at all. the protector does not go all the way to the edge, and cutouts for the home button are off.\n2. The feel of the protector is horrible. Imagine rubbing your finger over a rubber band--it is somewhat grippy. Not smooth at all.\n3. Once applied (also impossible to apply with no air bubbles) the screen protector has a look similar to spraying water over an older CRT television.\n\nI will be asking for a refund.\n\n** Update ** I sent the item back on my dime, and Spigen refuses to issue me a refund. DO NOT DO BUSINESS WITH THEM!!!",
#   "Okay, I hate to give a bad review on anything, but I'm really disappointed with this product.\n\nPros:\nGreat price\nEasy, bubble-free install\n\nCons:\nOleophobic coating lasted on the first glass protector screen for . . . 2 days.\nOleophobic coating on second glass protector screen (installed because the first screen became so annoying as it was no longer clear) lasted for . . . less than one day.\n\nAfter wiping with a soft cloth, portions of the screen protector would not come clean. For instance, a center diagonal would wipe clean, but the corners would not, and there are distinct lines where the clean/unclean areas are. Most annoying.\n\nSince I did get three in the pack, I guess I'll see how the third one does, but I'm not holding my breath.\n\nI really loved this screen protector: http://smile.amazon.com/gp/product/B00CD0I8EK?psc=1&redirect=true&ref_=oh_aui_detailpage_o05_s00\nThe oleophobic coating was amazing on it . . . for about 4 months, sigh.\n\nStill searching for a long-lasting oleophobic coated screen protector . . .",
#   "This is my worse Amazon purchase ever! I decided to try this organizer as I already have a similar unit that works well for my needs only its much sturdier w/ heavy duty zippers. This unit is like heavy plastic wrap. The shoe slats are barely tacked. I barely got two pairs of shoes loaded before one broke. It only has a single zipper which is more like doll clothing quality. I don't expect it to last a month. If I had gotten this package in a reasonable time line, maybe I would be over it, but I had to wait more than a month and a half for this disappointment. I've ordered items that were shipped internationally before and they have never taken this long. This turned out to be a definite waste of time and money.",
#   "I usually don't leave negative feedback, but this product seems to call for it. It was not a welcome addition to my craft tools. Unsteady standing; glue catch below tip of glue gun came loose; not satisfactory in any way. Went into trash. Sorry. Had looked forward to using it."]}

# %%
new_train_set_records = []
for inde, row in tqdm(train_set.iterrows(), total=len(train_set)):
    current_label = row["label"]
    current_text = row["text"]
    for example in centroid_examples[current_label]:
        new_train_set_records.append({"text": current_text, "label": example, "class": current_label})

rewrite_train_set = pd.DataFrame(new_train_set_records).sample(frac=1).reset_index(drop=True)
rewrite_train_set.to_csv("datasets/corrupted/boss_sentiment_train.csv", index=False)
display(rewrite_train_set)

new_test_set_records = []
for inde, row in tqdm(test_set.iterrows(), total=len(test_set)):
    current_label = row["label"]
    current_text = row["text"]
    for example in centroid_examples[current_label]:
        new_test_set_records.append({"text": current_text, "label": example, "class": current_label})

rewrite_test_set = pd.DataFrame(new_test_set_records).sample(frac=1).reset_index(drop=True)
rewrite_test_set.to_csv("datasets/corrupted/boss_sentiment_test.csv", index=False)
display(rewrite_test_set)
# Out:
# 100%|██████████| 29999/29999 [00:01<00:00, 27024.60it/s]
#                                                      text  \
# 0       I wasn't expecting much... But These Things Ar...
# 1       These post bases are a great product for keepi...
# 2                                It was ok for the money.
# 3       This game is simply ok. It's not a great follo...
# 4       Hands down the best tasting boxed pasta out th...
# ...                                                   ...
# 299985  Installed with a new gasket/insulator kit boug...
# 299986  If you are a homemade bread baker and you like...
# 299987                              not vey good. just ok
# 299988  This is pretty much the worst toaster oven we ...
# 299989  I have had the smaller 7ft version of this umb...
#
#                                                     label  class
# 0       Do not buy.. I've been pleased with the normal...      0
# 1       Really a very nice product. Works great and so...      1
# 2       The ends are fairly sharp, but some were dulle...      2
# 3       The AmazonBasics calculator is decent but not ...      2
# 4                        Great product, highly recommend.      1
# ...                                                   ...    ...
# 299985  Works perfectly for what I need it for. Feels ...      1
# 299986                   Great product, highly recommend.      1
# 299987  I was expecting this to be a little easier tha...      2
# 299988  SB has terrible customer service, Never return...      0
# 299989  Worst filament I have purchased to date. Very ...      0
#
# [299990 rows x 3 columns]
# 100%|██████████| 38904/38904 [00:01<00:00, 26713.20it/s]
#                                                      text  \
# 0       I use this every day I would recommend this fo...
# 1       This was a gift for a one year old. It's a gre...
# 2                        Good fit for the iPhone 6s Plus.
# 3       Great starter kit. A good purchase and it's a ...
# 4       Lovely shade of pink. Not your Grandma's pink,...
# ...                                                   ...
# 389035  This product was researched by a co worker for...
# 389036  As described! My 4 year old loves Legos and pl...
# 389037  They work awesome. I am on a well and at 45lbs...
# 389038              Best battery I ever had, Kicks ass...
# 389039  The stand is lightweight, easy to setup and wo...
#
#                                                     label  class
# 0                           Excellent product, I love it.      1
# 1       Really Great Product, soildly built, More than...      1
# 2       Works perfectly for what I need it for. Feels ...      1
# 3                        Great product, highly recommend.      1
# 4                                          Great product.      1
# ...                                                   ...    ...
# 389035                      Excellent product, I love it.      1
# 389036  Really Great Product, soildly built, More than...      1
# 389037                               I like this product.      1
# 389038                               I like this product.      1
# 389039  Works perfectly for what I need it for. Feels ...      1
#
# [389040 rows x 3 columns]
