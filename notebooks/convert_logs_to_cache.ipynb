# %%
from datasets import Dataset, DatasetDict
from tqdm import tqdm
import pandas as pd
import json
import wandb
import os
import hashlib
tqdm.pandas()

# %% [markdown]
# ## Upload Local Cache to HF

# %%
cache_dir = "../cached_rewrites"
cache_files = os.listdir(cache_dir)
combined_dataset_dict = DatasetDict()
for cache_file in tqdm(cache_files):
    frame = pd.read_csv(os.path.join(cache_dir, cache_file), engine="python", on_bad_lines="skip")
    dataset = Dataset.from_pandas(frame)
    cache_split_name = cache_file.replace(".csv", "").replace(".", "dot").replace("=", "equals").replace("-", "_")
    combined_dataset_dict[cache_split_name] = dataset

combined_dataset_dict
# Out:
# 100%|██████████| 13/13 [00:19<00:00,  1.46s/it]
# DatasetDict({
#     boss_sentiment_aug_back_translate: Dataset({
#         features: ['prompt_hash', 'prompt', 'rewrites'],
#         num_rows: 61580
#     })
#     boss_toxicity_aug_back_translate: Dataset({
#         features: ['prompt_hash', 'prompt', 'rewrites'],
#         num_rows: 116807
#     })
#     ag_news_twitter_aug_back_translate: Dataset({
#         features: ['prompt_hash', 'prompt', 'rewrites'],
#         num_rows: 15200
#     })
#     boss_sentiment_aug_substitute: Dataset({
#         features: ['prompt_hash', 'prompt', 'rewrites'],
#         num_rows: 61580
#     })
#     boss_sentiment_stabilityai_StableBeluga_13B_tempequals0dot0: Dataset({
#         features: ['prompt_hash', 'prompt', 'rewrites'],
#         num_rows: 2132
#     })
#     ag_news_twitter_aug_insert: Dataset({
#         features: ['prompt_hash', 'prompt', 'rewrites'],
#         num_rows: 15200
#     })
#     boss_toxicity_aug_substitute: Dataset({
#         features: ['prompt_hash', 'prompt', 'rewrites'],
#         num_rows: 120032
#     })
#     ag_news_twitter_aug_substitute: Dataset({
#         features: ['prompt_hash', 'prompt', 'rewrites'],
#         num_rows: 15200
#     })
#     boss_sentiment_aug_insert: Dataset({
#         features: ['prompt_hash', 'prompt', 'rewrites'],
#         num_rows: 61580
#     })
#     boss_toxicity_aug_insert: Dataset({
#         features: ['prompt_hash', 'prompt', 'rewrites'],
#         num_rows: 120032
#     })
#     boss_toxicity_stabilityai_StableBeluga_7b_tempequals0dot0: Dataset({
#         features: ['prompt_hash', 'prompt', 'rewrites'],
#         num_rows: 187167
#     })
#     boss_sentiment_stabilityai_StableBeluga_7b_tempequals0dot0: Dataset({
#         features: ['prompt_hash', 'prompt', 'rewrites'],
#         num_rows: 123133
#     })
#     ag_news_twitter_stabilityai_StableBeluga_7b_tempequals0dot0: Dataset({
#         features: ['prompt_hash', 'prompt', 'rewrites'],
#         num_rows: 30400
#     })
# })

# %%
combined_dataset_dict.push_to_hub("Kyle1668/LLM-TTA-Cached-Rewrites")
# Out:
# Creating parquet from Arrow format: 100%|██████████| 62/62 [00:00<00:00, 143.14ba/s]
# Uploading the dataset shards: 100%|██████████| 1/1 [00:03<00:00,  3.97s/it]
# Creating parquet from Arrow format: 100%|██████████| 117/117 [00:00<00:00, 139.39ba/s]
# Uploading the dataset shards: 100%|██████████| 1/1 [00:05<00:00,  5.01s/it]
# Creating parquet from Arrow format: 100%|██████████| 16/16 [00:00<00:00, 138.21ba/s]
# Uploading the dataset shards: 100%|██████████| 1/1 [00:00<00:00,  1.20it/s]
# Creating parquet from Arrow format: 100%|██████████| 62/62 [00:00<00:00, 125.65ba/s]
# Uploading the dataset shards: 100%|██████████| 1/1 [00:02<00:00,  2.27s/it]
# Creating parquet from Arrow format: 100%|██████████| 3/3 [00:00<00:00, 108.17ba/s]
# Uploading the dataset shards: 100%|██████████| 1/1 [00:00<00:00,  1.88it/s]
# Creating parquet from Arrow format: 100%|██████████| 16/16 [00:00<00:00, 122.38ba/s]
# Uploading the dataset shards: 100%|██████████| 1/1 [00:00<00:00,  1.16it/s]
# Creating parquet from Arrow format: 100%|██████████| 121/121 [00:00<00:00, 137.47ba/s]
# Uploading the dataset shards: 100%|██████████| 1/1 [00:03<00:00,  3.94s/it]
# Creating parquet from Arrow format: 100%|██████████| 16/16 [00:00<00:00, 127.85ba/s]
# Uploading the dataset shards: 100%|██████████| 1/1 [00:00<00:00,  1.03it/s]
# Creating parquet from Arrow format: 100%|██████████| 62/62 [00:00<00:00, 105.97ba/s]
# Uploading the dataset shards: 100%|██████████| 1/1 [00:03<00:00,  3.55s/it]
# Creating parquet from Arrow format: 100%|██████████| 121/121 [00:00<00:00, 140.17ba/s]
# Uploading the dataset shards: 100%|██████████| 1/1 [00:04<00:00,  4.76s/it]
# Creating parquet from Arrow format: 100%|██████████| 94/94 [00:00<00:00, 112.99ba/s]
# Creating parquet from Arrow format: 100%|██████████| 94/94 [00:00<00:00, 142.08ba/s]
# Uploading the dataset shards: 100%|██████████| 2/2 [00:06<00:00,  3.36s/it]
# Creating parquet from Arrow format: 100%|██████████| 124/124 [00:00<00:00, 154.18ba/s]
# Uploading the dataset shards: 100%|██████████| 1/1 [00:03<00:00,  3.60s/it]
# Creating parquet from Arrow format: 100%|██████████| 31/31 [00:00<00:00, 136.03ba/s]
# Uploading the dataset shards: 100%|██████████| 1/1 [00:01<00:00,  1.53s/it]
# README.md: 100%|██████████| 3.08k/3.08k [00:00<00:00, 2.23MB/s]

# %% [markdown]
# ## Update Local ID Toxicity Paraphrase Cache

# %%
local_paths = [
    "data/BOSS_Toxicity_ID_BERT_Paraphrase/validation_stabilityai/StableBeluga-7b_random_0_Kyle1668/boss-toxicity-bert-base-uncased_style_logs.table.json"
    ]
with open(local_paths[0], "r") as f:
    logs = json.load(f)

frame = pd.DataFrame(data=logs["data"], columns=logs["columns"])
frame.head(3)
# Out:
#     entropy                                   mean probs  \
# 0  0.000379  [0.9999665021896362, 3.351096893311478e-05]
# 1  0.000071   [0.9999946355819702, 5.39638949703658e-06]
# 2  0.000070  [0.9999946355819702, 5.326296559360344e-06]
#
#                                            all probs  \
# 0  [[0.9999673366546631, 3.262787504354492e-05], ...
# 1  [[0.9999946355819702, 5.372834948502714e-06], ...
# 2  [[0.9999945163726807, 5.43204214409343e-06], [...
#
#                                        all entropies    latency  \
# 0  [0.0003697199572343379, 0.0003697199572343379,...  12.172549
# 1  [7.055921741994098e-05, 6.757902883691713e-05,...   8.861567
# 2  [7.133732287911698e-05, 7.105202530510724e-05,...  10.273449
#
#                                                input  \
# 0  [<aug>As long as the children are at least 1/8...
# 1  [<aug>Begin by eliminating the Jones Act to al...
# 2  [<aug>There are usually only a few individuals...
#
#                                       original_input  \
# 0  As long as the children are at least 1/8 Nativ...
# 1  Start by flushing the Jones Act, in order to c...
# 2  There are usually very few people who run for ...
#
#                                         style prompt mean exemplar distance  \
# 0  ### System:\n### Instructions ###\nThe assista...                   None
# 1  ### System:\n### Instructions ###\nThe assista...                   None
# 2  ### System:\n### Instructions ###\nThe assista...                   None
#
#    judgment prompt  label  original judgment  original entropy  \
# 0         0   None      0                  0          0.000370
# 1         0   None      0                  0          0.000075
# 2         0   None      0                  0          0.000068
#
#    entropy decrease  entropy decreased  \
# 0         -0.000009              False
# 1          0.000005               True
# 2         -0.000002              False
#
#                                       original probs            outcome
# 0  [[0.9999673366546631, 3.262787504354492e-05], ...  Unchanged Correct
# 1  [[0.9999946355819702, 5.372834948502714e-06], ...  Unchanged Correct
# 2  [[0.9999945163726807, 5.43204214409343e-06], [...  Unchanged Correct

# %%
def parse_augmentations(augmentations):
    if augmentations is None or len(augmentations) == 0:
        return []

    return [aug.replace("<aug>", "").replace("</aug>", "") for aug in augmentations[:4]]

cache_frame = frame[["style prompt", "input"]]
cache_frame = cache_frame.rename(columns={"style prompt": "prompt", "input": "rewrites"})
cache_frame["rewrites"] = cache_frame["rewrites"].progress_apply(parse_augmentations)
cache_frame["prompt_hash"] = cache_frame["prompt"].progress_apply(lambda prompt: hashlib.sha256(prompt.encode()).hexdigest())
cache_frame = cache_frame[["prompt_hash", "prompt", "rewrites"]]
cache_frame
# Out:
# 100%|██████████| 97320/97320 [00:00<00:00, 112407.73it/s]
# 100%|██████████| 97320/97320 [00:00<00:00, 214786.25it/s]
#                                              prompt_hash  \
# 0      d1206639cb51475f51c28ef43f1b25ff0f2db0d974ac6c...
# 1      fbeaf936c124e90d6264efa2639c102331529aa6c3355f...
# 2      cde3bf7c31dd80958e36415bb747f1c146d9c01b2129ce...
# 3      9c6b0c50babdd4c7faf3e791d67cabe6f27d0d0437ee5e...
# 4      43b49cdd4de5087254158d300715eaf1a79d1fcd5c83ff...
# ...                                                  ...
# 97315  5ae75a6b84dbf7e7dcbd636be61bb7204f1a27796ea986...
# 97316  3bd4d0541489de0a8d2dea5a2adff3bf1272b69b7a60f6...
# 97317  ace9dad5250b6d5ec01a6c1c41b6273b38088839b74583...
# 97318  4b7f32ca2e68b7070a316aec9d1a8666885e58715ffc3a...
# 97319  a47c2bd72310a09b273fbb3c0f519c3049e0d24ed091af...
#
#                                                   prompt  \
# 0      ### System:\n### Instructions ###\nThe assista...
# 1      ### System:\n### Instructions ###\nThe assista...
# 2      ### System:\n### Instructions ###\nThe assista...
# 3      ### System:\n### Instructions ###\nThe assista...
# 4      ### System:\n### Instructions ###\nThe assista...
# ...                                                  ...
# 97315  ### System:\n### Instructions ###\nThe assista...
# 97316  ### System:\n### Instructions ###\nThe assista...
# 97317  ### System:\n### Instructions ###\nThe assista...
# 97318  ### System:\n### Instructions ###\nThe assista...
# 97319  ### System:\n### Instructions ###\nThe assista...
#
#                                                 rewrites
# 0      [As long as the children are at least 1/8 Nati...
# 1      [Begin by eliminating the Jones Act to allevia...
# 2      [There are usually only a few individuals who ...
# 3      [People who disrespect Canada should consider ...
# 4      [If Trump has any sense of decency and persona...
# ...                                                  ...
# 97315  [Who would have thought that the media is fill...
# 97316  [Paraphased Text., Paraphased Text., A precede...
# 97317  [There are many individuals who were aware of ...
# 97318  [Attrition can be a tool to alleviate some of ...
# 97319  [It makes you wonder if Bowlen was in good hea...
#
# [97320 rows x 3 columns]

# %%
local_cache = "../cached_rewrites/boss_toxicity_stabilityai_StableBeluga-7b_temp=0.0_old.csv"
locale_cache_frame = pd.read_csv(local_cache)
locale_cache_frame
# Out:
#                                              prompt_hash  \
# 0      168011d03c4817b55e74ff37c024cdbc10ec0d28cf765b...
# 1      d7b591156972ab00b7243e114fefbb92f5a15725742062...
# 2      1595eef0d43e070a5484019b69aba7936de404813c65f8...
# 3      d30a5d45e551f91df05e769a51c837b06a42d82ebf58d1...
# 4      76a7edfe87a60ae2cc1bc4fce2a4dc245e3664b0c9fb4a...
# ...                                                  ...
# 90335  39c26f4a80526d1ece3b8c7551ebbddae82ec66b7992dc...
# 90336  a07c6e187a9fcba58a5d975aebdc0a4ee749dc35aa9472...
# 90337  e71aaef2eb5da5896dc74c3b7587bb0aadda66fb233596...
# 90338  ffaa0562187c550dcc153e02b21b3d0908859a956e8639...
# 90339  bc83ffd00f6f547af23df840b38f3286080890f14059f3...
#
#                                                   prompt  \
# 0      ### System:\n### Instructions ###\nThe assista...
# 1      ### System:\n### Instructions ###\nThe assista...
# 2      ### System:\n### Instructions ###\nThe assista...
# 3      ### System:\n### Instructions ###\nThe assista...
# 4      ### System:\n### Instructions ###\nThe assista...
# ...                                                  ...
# 90335  ### System:\n### Instructions ###\nThe assista...
# 90336  ### System:\n### Instructions ###\nThe assista...
# 90337  ### System:\n### Instructions ###\nThe assista...
# 90338  ### System:\n### Instructions ###\nThe assista...
# 90339  ### System:\n### Instructions ###\nThe assista...
#
#                                                 rewrites
# 0      ['While some members of Congress maintain stro...
# 1      ['The original inhabitants of the land have a ...
# 2      ["It's not about who you sleep with, but rathe...
# 3      ["I support women's rights, but I'm not entire...
# 4      ['It is a significant matter in the Bible when...
# ...                                                  ...
# 90335  ['The text is already paraphrased.', 'The text...
# 90336  ["Sounds like Butts provided the Health Minist...
# 90337  ['I agree, so establish free clinics where tho...
# 90338  ["A deal that will make us uncompetitive and f...
# 90339  ["On which planet do you reside? Of course, ev...
#
# [90340 rows x 3 columns]

# %%
# find records between local_cache and cache_frame where the prompt_hash are the same
new_cache = pd.concat([locale_cache_frame, cache_frame]).drop_duplicates(subset=["prompt_hash"], keep="last")
new_cache.to_csv(local_cache.replace("_old", ""), index=False)
new_cache
# Out:
#                                              prompt_hash  \
# 0      168011d03c4817b55e74ff37c024cdbc10ec0d28cf765b...
# 1      d7b591156972ab00b7243e114fefbb92f5a15725742062...
# 2      1595eef0d43e070a5484019b69aba7936de404813c65f8...
# 3      d30a5d45e551f91df05e769a51c837b06a42d82ebf58d1...
# 4      76a7edfe87a60ae2cc1bc4fce2a4dc245e3664b0c9fb4a...
# ...                                                  ...
# 97315  5ae75a6b84dbf7e7dcbd636be61bb7204f1a27796ea986...
# 97316  3bd4d0541489de0a8d2dea5a2adff3bf1272b69b7a60f6...
# 97317  ace9dad5250b6d5ec01a6c1c41b6273b38088839b74583...
# 97318  4b7f32ca2e68b7070a316aec9d1a8666885e58715ffc3a...
# 97319  a47c2bd72310a09b273fbb3c0f519c3049e0d24ed091af...
#
#                                                   prompt  \
# 0      ### System:\n### Instructions ###\nThe assista...
# 1      ### System:\n### Instructions ###\nThe assista...
# 2      ### System:\n### Instructions ###\nThe assista...
# 3      ### System:\n### Instructions ###\nThe assista...
# 4      ### System:\n### Instructions ###\nThe assista...
# ...                                                  ...
# 97315  ### System:\n### Instructions ###\nThe assista...
# 97316  ### System:\n### Instructions ###\nThe assista...
# 97317  ### System:\n### Instructions ###\nThe assista...
# 97318  ### System:\n### Instructions ###\nThe assista...
# 97319  ### System:\n### Instructions ###\nThe assista...
#
#                                                 rewrites
# 0      ['While some members of Congress maintain stro...
# 1      ['The original inhabitants of the land have a ...
# 2      ["It's not about who you sleep with, but rathe...
# 3      ["I support women's rights, but I'm not entire...
# 4      ['It is a significant matter in the Bible when...
# ...                                                  ...
# 97315  [Who would have thought that the media is fill...
# 97316  [Paraphased Text., Paraphased Text., A precede...
# 97317  [There are many individuals who were aware of ...
# 97318  [Attrition can be a tool to alleviate some of ...
# 97319  [It makes you wonder if Bowlen was in good hea...
#
# [187167 rows x 3 columns]
